# %% [markdown]
# # Exam 5 - Final

# %% [markdown]
# ---
#
# **(1.)** Evaluate each of the following:
#
# **a)** $\frac{d}{dx}\frac{\ln(x)}{x^2}$
#
# quotient rule: $\frac{f'\cdot g - g'\cdot f}{g^2}$
#
# $\frac{\frac{d}{dx}(\ln(x))x^2 - \frac{d}{dx}(x^2)\ln(x)}{(x^2)^2}$
# $\;=\; \frac{\frac{1}{x}x^2-2x\ln(x)}{x^4}$
# $\;=\; \frac{1-2\ln(x)}{x^3}$
#
# **answer:** $\;\frac{1-2\ln(x)}{x^3}$
#
# <br>
#
# **b)** $\frac{d}{du}\sqrt{3\sin^2(u)+2}$
#
# chain rule: $\frac{df(u)}{dx} = \frac{df}{du} \cdot \frac{du}{dx}$
#
# Let $f=\sqrt{v},\; v=3\sin^2(u)+2$
#
# $\frac{d}{dv}(\sqrt{v})\frac{d}{du}(3\sin^2(u)+2)$
# $\;=\; \frac{1}{2\sqrt{v}}\frac{d}{du}(3sin^2(u)+2$
#
# $\frac{1}{2\sqrt{3\sin^2(u)+2}}\frac{d}{du}(3\sin^2(u)+2$
# $\;=\; \frac{3\sin(2u)}{2\sqrt{3\sin^2(u)+2}} $
#
# **answer:** $\frac{3\sin(2u)}{2\sqrt{3\sin^2(u)+2}}$
#
# <br>
#
# **c)** $\frac{d^n}{dx^n}e^{kx} \big|_{x=0}$
#
# $\frac{d^n}{dx^n} \implies$ nth derivative
#
# $k^ne^x\big|_{x=0} = k^n$
#
# **answer:** $\;k^n$

# %% [markdown]
# ---
# **(2.)** Find the equation of the line tangent to the graph of $x^2y^2+y^3=2$ at the point (1,1) on the graph. (Give the equation in the form $y=mx+b$)
#
#
# implicit differentiation: $\frac{dy}{dx}(x^2y^2+y^3) = 2$
#
# $\frac{d}{dx}(x^2y^2+y^3) = \frac{d}{dx}(2)$
#
# $2xy^2 + 2y\frac{d}{dx}(y)x^2 + 3y^2\frac{d}{dx}(y) = 0$
#
# $2y\frac{d}{dx}(y)x^2 + 3y^2\frac{d}{dx}(y) = -2xy^2$
#
# $y\frac{d}{dx}(y)(2x^2+3y) = -2xy^2$
#
# $\frac{d}{dx}(y) = -\frac{2xy^2}{y(2x^2+3y)}$
#
# $\frac{d}{dx}(y) = -\frac{2xy}{2x^2+3y}$
#
# at (1,1) $\implies -\frac{2(1)(1)}{2(1)^2+3(1)} = -\frac{2}{5}$
#
# $(y-y_0) = -\frac{2}{5}(x-1) \implies y = -\frac{2}{5}x+\frac{2}{5}$
#
# **answer:** $y = -\frac{2}{5}x + \frac{2}{5}$

# %% [markdown]
# ---
# **(3.)** Using implicit differentiation, derive the formula for $D\cos^{-1}x$ by using the formula for $D\cos x$ (Let $y=\cos^{-1}x$)
#
# $y = \cos^{-1}x \implies x = \cos y$
#
# $\frac{d}{dx}(\cos^{-1}x) = -\frac{1}{\sqrt{1-cos^2y}}$
#
# $\frac{d}{dx} = -\frac{1}{\sqrt{1-x^2}}$

# %% [markdown]
# ---
#
# **(5.)** On a night when the full moon is directly overhead, an outdoor Christmas tree 50 feet high is falling over. Its top is falling at the rate of 2 feet/sec, at the moment when it is 30 feet from the ground. At that moment, how rapidly is the shadow of the tree cast by the moon lengthening?
#
# $x^2+y^2 = 50^2$
#
# $x^2 + (30)^2 = 50^2 \implies x = \sqrt{1600} = 40$
#
# $2x\frac{dx}{dt} + 2y\frac{dy}{dt} = 0$
#
# $2(40)\frac{dx}{dt} + 2(30)\frac{dy}{dt} = 0$
#
# $\frac{dy}{dt} = -2$ (falling)
#
# $80\frac{dx}{dt} + 60(-2) = 0$
#
# $80\frac{dx}{dt} = 120$
#
# $\frac{dx}{dt} = \frac{120}{80} = \frac{3}{2}$
#
# **answer:** $\frac{3}{2}$ ft/s

# %% [markdown]
# ---
#
# **(6.)** Find the area of the largest rectangle whose base lies along the x-axis and whose top corners lie on the parabola $y=1-x^2$
#
# $A=2xL = 2x(1-x^2) = 2x-2x^3 $
#
# $\frac{dA}{dt} = 2-6x^2$
#
# $2-6x^2 = 0$
# $\implies 2 = 6x^2$
# $\implies \frac{1}{3}=x^2$
# $\implies \frac{1}{\sqrt{3}}=x$
#
# $A = \frac{2}{\sqrt{3}}(1-(\frac{1}{\sqrt{3}})^2)$
# $\;=\; \frac{4}{3\sqrt{3}}$
#
# **answer:** $\frac{4}{3\sqrt{3}}$

# %% [markdown]
# ---
#
# **(8.)** The cup of a wine glass has the shape formed by rotating the parabola $y=x^2$ about the y-axis; its upper rim is a circle of radius 1. How much wine does it hold?
#
# $V = \int_0^1 2\pi x(1-x^2)dx$
#
# $2\pi\big[\frac{x^2}{2} - \frac{x^4}{4}\big]_0^1$
# $\;=\; 2\pi [(\frac{1}{2}-\frac{1}{4}) - 0] = 2\pi\frac{1}{4}$
# $\;=\; \frac{\pi}{2}$
#
# **answer:** $\frac{\pi}{2}$

# %% [markdown]
# ---
# **(9.)** Using the trapezoidal rule with three subdivisions (n=3), estimate $\int_0^{\pi/2}\sin^2(x)dx$.
#
#
# $ 0 \to \frac{\pi}{2} \implies \{0, \frac{\pi}{6}, \frac{\pi}{3},\frac{\pi}{2}\}$
#
# $\sin(x)$
# $\quad \sin(0)=0$
# $\quad \sin(\frac{\pi}{6}) = \frac{1}{2}$
# $\quad \sin(\frac{\pi}{3}) = \frac{\sqrt{3}}{2}$
# $\quad \sin(\frac{\pi}{2}) = 1$
#
# $\sin^2(x)$
# $\quad\sin^2(0)=0$
# $\quad\sin^2(\frac{\pi}{6})=\frac{1}{4}$
# $\quad\sin^2(\frac{\pi}{3})=\frac{3}{4}$
# $\quad\sin^2(\frac{\pi}{2})=1$
#
# $\frac{\pi}{6}(\frac{1}{2}(0) + \frac{1}{4} + \frac{3}{4} + \frac{1}{2}(1))$
# $\;=\; \frac{\pi}{6}(1+\frac{1}{2})$
# $\;=\; \frac{\pi}{4}$
#
# **answer:** $\; \frac{\pi}{4}$

# %% [markdown]
# ---
#
# **(10.)** Let $F(x) = \int_0^x e^{-t^2}dt$
#
# **a)** Find $F'(1)$ $F''(1)$
#
# $F'(x) = e^{-x^2} \implies F'(1) = \frac{1}{e}$
#
# $F''(x) = -2xe^{-x^2} \implies F''(1) = -\frac{2}{e}$
#
# <br>
#
# **b)** Express $\int_1^2 e^{\frac{-u^2}{4}}du$ in terms of values of $F(x)$
#
# let $t = \frac{u}{2} \implies dt=\frac{du}{2}$
#
# $\int_1^2 e^{\frac{-u^2}{4}} $
# $\;=\; \int_{1/2}^1 e^{-t^2}\cdot 2dt \quad$ (bound change)
#
# **answer:** $2[F(1)-F(\frac{1}{2})]$

# %% [markdown]
# ---
#
#
# **(11.)** Between the two towers of a suspension bridge, each of the two main cables has the shape of the parabola $y=\frac{1}{10}x^2$ (in kilometers). The two towers are 2km apart; the vertical cables from the main cable to the horizontal roadway are closely and equally spaced.
#
# **a)** Set up a definite integral which gives the length of each main cable between the two towers.
#
# $y = \frac{x^2}{10} \implies y' = \frac{x}{5}$
#
# $2km \implies -1 \le x \le 1 \implies$ x centered at 0
#
# $\text{arclen} = \int_a^b \sqrt{1+(f'(x))^2}dx$
#
# $\int_{-1}^1 \sqrt{1+\frac{x^2}{25}}dx$
#
# **answer:** $\;\int_{-1}^1 \sqrt{1+\frac{x^2}{25}}dx$
#
# <br>
#
# **b)** What is the average length (to the nearest meter) of the vertical cables?
#
# $\int_{-1}^1 \frac{1}{2}\frac{x^2}{10}dx$
# $\;=\; \frac{1}{2} \int_{-1}^1 \frac{x^2}{10}dx$
# $\;=\; \frac{1}{2}\big[\frac{x^3}{30}\big]_{-1}^1$
#
# $\frac{1}{2}\big[ \frac{1}{30}+\frac{1}{30} \big]$
# $\;=\; \frac{1}{30}$
#
# **answer:** $\frac{1}{30}$ km = 33 m

# %% [markdown]
# ---
#
# **(12.)** Evaluate
#
# **a)** $\int_0^1\frac{dx}{x^2+3x+2}$
#
# let $u=x+\frac{3}{2}$
#
# $\frac{d}{dx}(x+\frac{3}{2}) = 1 \implies du=1dx,\; dx=1du$
#
# $\int\frac{1}{u^2-\frac{1}{4}}du$
# $\;=\; \int\frac{4}{4u^2-1}du$
#
# $x=0 \implies u=\frac{3}{2},\quad\quad x=1 \implies u=\frac{5}{2}$
#
# $\int_{3/2}^{5/2}\frac{4}{4u^2-1}du$
# $\;=\; 4\int_{3/2}^{5/2} \frac{1}{4u^2-1}du$
# $\;=\; -4\int_{3/2}^{5/2} \frac{1}{-4u^2 + 1}du$
#
# <br>
#
# let $v=\frac{1}{2}v$
#
# $\frac{d}{du}(\frac{1}{2}v) = \frac{1}{2} \implies du=\frac{1}{2}dv$
#
# $\int \frac{1}{-4(\frac{1}{2}v)^2+1}\cdot\frac{1}{2}dv$
# $\;=\; \int\frac{1}{2(-v^2+1)}dv$
#
# $u=\frac{3}{2} \implies v=3 \quad\quad u=\frac{5}{2} \implies v=5$
#
# $4(-\int_3^5 \frac{1}{2(-v^2+1)}dv)$
# $\;=\;4(-\frac{1}{2}\big[ \frac{\ln|v+1|}{2} - \frac{\ln|v-1|}{2} \big]_3^5$
#
# $-2\big[\frac{1}{2}(\ln|v+1| - \ln|v-1|)\big]_3^5$
#
# $-2[\frac{\ln(6) -2\ln(2)}{2} - \frac{\ln(2)}{2}]$
# $\;=\; -2\cdot\frac{\ln(6)-3\ln(2)}{2}$
# $\;=\; -\ln(6)+3\ln(2)$
#
# **answer:** $\; -\ln(6)+3\ln(2)$
#
# <br>
#
# **b)** $\int x^2\ln(x)dx$
#
# Integrate by parts: $\int uv' = uv-\int u'v$
#
# let $u=\ln(x),\; v'=x^2$
#
# $\ln(x)\frac{x^3}{3} - \int\frac{1}{x}\frac{x^3}{3}dx$
#
# **answer:** $\; \frac{x^3}{3}\ln(x) - \frac{x^3}{9} + C$

# %% [markdown]
# ---
#
# **(13.)** Evaluate $\int_0^1 \frac{dx}{(x^2+1)^2}$ by making the substitution $x=\tan u$; remember the limits
#
# let $x=\tan(u)$
#
# $\frac{d}{dv}(\tan(v)) = \sec^2(v) \implies dx=\frac{1}{\cos^2(u)}du$
#
# $\int \frac{1}{(\tan^2(u)+1)^2}\frac{1}{\cos^2(u)}du$
# $\;=\; \int \frac{1}{\sec^4(u)\cos^2(u)}du$
#
# $x=0 \implies u=0 \quad\quad x=1\implies u=\frac{\pi}{4}$
#
# $\int_0^{\pi/4}\frac{1}{\sec^4(u)\cos^2(u)}du$
# $\;=\; \int_0^{\pi/4}\frac{1}{(\frac{1}{\cos(u)})^4\cos^2(u)}du$
# $\;=\; \int_0^{\pi/4}\cos^2(u)du$
#
# $\int_0^{\pi/4}\frac{1+\cos(2u)}{2}du$
# $\;=\; \frac{1}{2}\int_0^{\pi/4} 1+ \cos(2u)du$
# $\;=\; \frac{1}{2}\big[ \int_0^{\pi/4}1du + \int_0^{\pi/4}\cos(2u)du \big]$
#
# $\frac{1}{2}\big[ \frac{\pi}{4}+\frac{1}{2} \big]$
# $\;=\; \frac{\pi+2}{8}$
#
# **answer:** $\;\frac{\pi+2}{8}$

# %% [markdown]
# ---
#
# **(14.)** Starting at the point where $r=1$, the point $P$ moves counterclockwise along the polar curve $r=e^{\theta/2\pi}$, in such a way that the line segment $OP$ makes one complete revolution. (Here $O$ denotes the origin.)
#
# Sketch the curve and find the total area swept out by $OP$ as it makes the revolution.
#
# $A = \int_\alpha^\beta \frac{1}{2}r^2 d\theta$
#
# $A = \frac{1}{2} \int_0^{2\pi} (e^{\theta/2\pi})^2 d\theta$
#
# let $u=\frac{\theta}{2\pi}$
#
# $\frac{d}{d\theta}(\frac{\theta}{2\pi}) = \frac{1}{2\pi} \implies du=\frac{1}{2\pi}d\theta,\; d\theta=2\pi du$
#
# $\frac{1}{2}\int_0^{2\pi} (e^{u})^2 2\pi du$
#
# $\theta=0 \implies u=0 \quad\quad \theta=2\pi \implies u=1$
#
# $\frac{1}{2}\int_0^1 2\pi e^{2u}du$
# $\;=\; \pi \int_0^1e^{2u}du$
#
# <br>
#
# let $v=2u$
#
# $\frac{d}{du}(2u) = 2 \implies dv=2du,\;du=\frac{1}{2}dv$
#
# $\pi\int_0^1 e^v \frac{1}{2}dv$
#
# $u=0 \implies v=0 \quad\quad u=1 \implies v=2$
#
# $\frac{\pi}{2}\int_0^2 e^v dv$
# $\;=\; \frac{\pi}{2}\big[ e^v \big]_0^2$
# $\;=\; \frac{\pi}{2}(e^2 - 1)$
#
# **answer:** $\; \frac{\pi}{2}(e^2 - 1)$

# %% [markdown]
# ---
#
# **(15.)** Evaluate
#
# **a)** $\lim_{x\to 0}\frac{\sin^2x}{1-\cos x}$
#
# $\frac{1-\cos^2(x)}{1-\cos(x)}$
# $\;=\; -\frac{(\cos(x)+1)(\cos(x)-1)}{1-\cos(x)}$
# $\;=\; \cos(x)+1$
#
# $\lim_{x\to 0}(\cos(x)+1)$
# $\;=\; \cos(0)+1$
# $\;=\; 2$
#
# **answer:** $\;2$
#
# <br>
#
# **b)** $\lim_{x\to 1}\frac{(\ln(x))^2}{x-1}$
#
# L'Hopital: if $\; \lim_{x\to a}\frac{f(x)}{g(x)} = \frac{0}{0}$ or $\frac{\pm\infty}{\pm\infty}$
#
# then $\quad \lim_{x\to a} \left( \frac{f(x)}{g(x)} \right) = \lim_{x\to a} \left( \frac{f'(x)}{g'(x)} \right)$
#
# <br>
#
# $\lim_{x\to 1}(\ln(x)^2) = 0$
#
# $\lim_{x\to 1}(x-1) = 0$
#
# $\lim_{x\to 1}\left( \frac{(\ln(x)^2)'}{(x-1)'} \right)$
# $\;=\; \lim_{x\to 1}\left( \frac{\frac{2\ln(x)}{x}}{1} \right)$
# $\;=\; \lim_{x\to 1}\left( \frac{2\ln(x)}{x} \right)$
#
# $\frac{2\ln(1)}{1} = 0$
#
# **answer:** $\; 0$
#
# <br>
#
# **c)** $\lim_{x\to\infty} x^2 e^{-x}$
#
# L'hopital again: see part (b)
#
# $\lim_{x\to\infty}(x^2) = \infty$
#
# $\lim_{x\to\infty}(\frac{1}{e^{-x}}) = \infty$
#
# $\lim_{x\to\infty}\left( \frac{(x^2)'}{(\frac{1}{e^{-1}})'} \right)$
# $\;=\; \lim_{x\to\infty} \left( \frac{2x}{e^x} \right)$
#
# $\frac{\infty}{\infty}\implies$
# $\lim_{x\to\infty}\frac{2}{e^x}$
# $\;=\; 2\cdot\lim_{x\to\infty}(\frac{1}{e^x})$
#
# $2\frac{\lim_{x\to\infty}(1)}{\lim_{x\to\infty}(e^x)}$
# $\;=\; 2\frac{1}{\infty}$
# $\;=\; 0$
#
# **answer:** $\; 0$

# %% [markdown]
# ---
#
# **(16.)** Evaluate $\int_1^\infty \frac{dx}{x^{3/2}}$
#
# $\int \frac{1}{x^{3/2}}dx$
# $\;=\; \int x^{-3/2}dx$
# $\;=\; \frac{x^{-1/2}}{-\frac{1}{2}}$
# $\;=\; -\frac{2}{x^{1/2}}$
# $\;=\;-2x^{-1/2} + C$
#
# $\lim_{x\to 1^+}(-2x^{-1/2}) - \lim_{x\to \infty}(-2x^{-1/2}) = 0 - (-2) = 2$
#
# **answer:** $\; 2$

# %% [markdown]
# ---
#
# **(17.)** For what values of $p$ does $\sum\limits_{1}^\infty \frac{n}{\sqrt{4 + n^p}}$ converge?
#
# $\frac{n}{\sqrt{4+n^p}}$
# $\approx \frac{n}{n^{p/2}}$
# $\approx \frac{1}{n^{(p/2) - 1}}$
#
# $\frac{p}{2}-1 > 1$
# $\implies \frac{p}{2} > 2$
# $\implies p > 4$
#
# **answer:** converges when $p > 4$

# %% [markdown]
# ---
#
# **(18.)**
#
# **a)** Find by differentiating the function $f(x)=\sqrt{1+x}$ the first four non-zero terms of its Taylor series around $x=0$.
#
# Taylor series: $f(x) = f(a)+\frac{f'(a)}{1!}(x-a) + \frac{f''(a)}{2!}(x-a)^2 + \ldots$
#
# $(1+(0))^{1/2} \;=\; 1$
#
#
# $\frac{d}{dx}(\sqrt{1+x})$
# $\;=\; \frac{1}{2}(1+x)^{-1/2}$
# $\;=\; \frac{1}{2}(1+(0))^{-1/2}$
# $\;=\; \frac{1}{2}$
#
# $\frac{d^2}{dx^2}(\frac{1}{2}(1+x)^{-1/2})$
# $\;=\; \frac{-1}{4}(1+x)^{-3/2}$
# $\;=\; \frac{-1}{4}(1+(0))^{-3/2}$
# $\;=\; \frac{-1}{4}$
#
# $\frac{d^3}{dx^3}(\frac{-1}{4}(1+x)^{-3/2})$
# $\;=\; \frac{3}{8}(1+x)^{-5/2}$
# $\;=\; \frac{3}{8}(1+(0))^{-5/2}$
# $\;=\; \frac{3}{8}$
#
# <br>
#
# **b)** Use the correct answer to (a) to calculate $\sqrt{1.2}$ to four decimal places.
#
# $(1+x)^{1/2} = 1 + \frac{1}{2}x -\frac{1}{8}x^2 + \frac{1}{16}x^3$
#
# $(1+\frac{2}{10})^{1/2} = 1+\frac{1}{2}(\frac{2}{10})-\frac{1}{8}(\frac{2}{10})^2-\frac{1}{16}(\frac{2}{10})^3$
#
# $(1+\frac{2}{10})^{1/2} = 1+\frac{1}{2}(\frac{2}{10}-\frac{1}{8}(\frac{4}{100})+\frac{1}{16}(\frac{8}{100})$
#
# $(1+\frac{2}{10})^{1/2} = 1 + 0.1 - 0.005 + 0.0005$
# $\;=\; 1.0955$
#
# **answer:** $\; 1.0955$

# %% [markdown]
# **(19.)** Find the Taylor series for $\tan^{-1}x$ around $x=0$ by using term-by-term differentiation or integration on the appropriate geometric series. Give enough terms to make the pattern clear.
#
#
# Taylor series: $f(x) = f(a)+\frac{f'(a)}{1!}(x-a) + \frac{f''(a)}{2!}(x-a)^2 + \ldots$
#
# $\tan^{-1}(0) = 0$
#
# $\frac{d}{dx}(\tan^{-1}x)$
# $\;=\; \frac{1}{x^2+1}$
#
# $0 + \frac{1}{1!}x + \frac{0}{2!}x^2 + \frac{-2}{3!}x^3 + \frac{0}{4!}x^4 + \frac{24}{5!}x^5 + \frac{0}{6!}x^6$
# $+\frac{-720}{7!}x^7 + \frac{0}{8!}x^8 + \ldots$
#
# $x-\frac{1}{3}x^3 + \frac{1}{5}x^5 -\frac{1}{7}x^7 + \ldots$
