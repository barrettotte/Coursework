# %% [markdown]
# # Chapter 13 - Vector Functions

# %% [markdown]
# **3.** Find a vector function that represents the curve of intersection of the cylinder $x^2+y^2=16$ and the plane $x+z=5$
#
# $x^2+y^2=r^2$
# $\implies x^2+y^2=4^2$
#
# $x+z=5 \Rightarrow z=5-x$
#
# $x=r\cos\theta,\quad y=r\sin\theta,\quad z=z$
#
# $4^2\cos^2 t + 4^2\sin^2 t = 16$
#
# $x=4\cos t,\quad y=4\sin t,\quad z=5-4\cos t$
#
# **answer:** $\overrightarrow{r} = \langle 4\cos t,\; 4\sin t,\; 5-4\cos t \rangle$

# %% [markdown]
# <hr>
#
# **5.** If $\boldsymbol{r}(t) = t^2\boldsymbol{i} + t\cos(\pi)t\boldsymbol{j} + \sin(\pi)t\boldsymbol{k}\;$, evaluate
# $\int_0^1 \boldsymbol{r}(t) dt$
#
# $\int_0^1 \langle t^2,\; t\cos(\pi t),\; \sin(\pi t) \rangle dt$
#
# <br>
#
# $\int t\cos(\pi t) dt$
#
# $\quad \text{let } u=t, v'=\cos(\pi t) \quad$ (integrate by parts)
#
# $\quad \int uv' = uv - \int u'v$
#
# $\quad u'=\frac{d}{dt}=1$
#
# $\quad v = \int\cos(\pi t)dt$
#
# $\quad\quad \text{let } u=\pi t$
# $\implies du=\pi dt,\quad dt=\frac{1}{\pi}du$
#
# $\quad\quad \int\cos(u)\frac{1}{\pi}du$
# $\;=\; \frac{1}{\pi}\int\cos(u)du$
# $\;=\; \frac{1}{\pi}\sin(u)$
#
# $\quad\quad v=\frac{1}{\pi}\sin(\pi t)$
#
# $\quad t\frac{1}{\pi}\sin(\pi t) - \int 1\cdot \frac{1}{\pi}\sin(\pi t)dt$
#
# $\quad \int \frac{1}{\pi}\sin(\pi t)dt$
#
# $\quad\quad \text{let } u=\pi t$
# $\implies du=\pi dt,\quad dt=\frac{1}{\pi}du$
#
# $\quad\quad \frac{1}{\pi}\int\sin(u)\frac{1}{\pi}du$
# $\;=\; \frac{1}{\pi^2}\int\sin(u)du$
# $\;=\; \frac{1}{\pi^2}(-\cos(u))$
#
# $\quad\quad\;=\; -\frac{1}{\pi^2}\cos(\pi t)$
#
# $\quad =\; \frac{\sin(\pi t)}{\pi}t + \frac{\cos(\pi t)}{\pi^2}$
#
# <br>
#
# $\int \sin(\pi t)dt$
#
# $\quad \text{let } u=\pi t$
# $\implies du=\pi dt,\; dt=\frac{1}{\pi}du$
#
# $\quad \int\sin(u)\frac{1}{\pi}du$
# $\;=\; \frac{1}{\pi}\int\sin(u)du$
#
# $\quad \frac{1}{\pi}(-\cos(u))$
# $\;=\; -\frac{\cos(\pi t)}{\pi}$
#
# <br>
#
# $= \langle \frac{t^3}{3},\;$
# $\frac{\sin(\pi t)}{\pi}t + \frac{\cos(\pi t)}{\pi^2},\;$
# $-\frac{\cos(\pi t)}{\pi}$
# $\rangle \big|_0^1$
#
# $= \langle (\frac{1}{3}-\frac{0}{3}),\;$
# $(\frac{\sin\pi}{\pi}+\frac{\cos\pi}{\pi^2})-(0+\frac{\cos(0)}{\pi^2}),\;$
# $(-\frac{\cos\pi}{\pi} - (-\frac{\cos(0)}{\pi}))$
# $\rangle$
#
# $= \langle \frac{1}{3},\; -\frac{1}{\pi^2}-\frac{1}{\pi^2},\;\frac{1}{\pi}+\frac{1}{\pi} \rangle$
#
# **answer:** $\langle \frac{1}{3},\; -\frac{2}{\pi^2},\; \frac{2}{\pi} \rangle$

# %% [markdown]
# <hr>
#
# **9.** The helix $\boldsymbol{r}_1(t) = \cos(t)\boldsymbol{i} + \sin(t)\boldsymbol{j} + t\boldsymbol{k}$ intersects the curve $\boldsymbol{r}_2(t) = (1+t)\boldsymbol{i} + t^2\boldsymbol{j} + t^3\boldsymbol{k}$ at the point $(1,0,0)$. Find the angle of intersection of these curves.
#
#
# let $t=0$
#
# $\overrightarrow{r_1}(t) = \langle 1,0,0 \rangle$
# $\quad \overrightarrow{r_2}(t) = \langle 1,0,0 \rangle$
#
# $\overrightarrow{r_1}\;'(t) = \langle -\sin t,\; \cos t,\; 1 \rangle$
#
# $\overrightarrow{r_2}\;'(t) = \langle 1,\; 2t,\; 3t^2 \rangle$
#
# <br>
#
# $\overrightarrow{a} = \overrightarrow{r_1}\;'(0)$
# $= \langle 0,1,1 \rangle$
#
# $\overrightarrow{b} = \overrightarrow{r_2}\;'(0)$
# $= \langle 1,0,0 \rangle$
#
# $\theta = \cos^{-1}\left( \frac{\overrightarrow{a}\cdot\overrightarrow{b}}{|\overrightarrow{a}||\overrightarrow{b}|} \right)$
#
# $\theta = \cos^{-1}\left( \frac{0(1)+1(0)+1(0)}{...} \right)$
# $\;=\; \cos^{-1}(0)$
#
# **answer:** $\frac{\pi}{2}$

# %% [markdown]
# <hr>
#
# **11.** For the curve given by $\boldsymbol{r}(t) = \langle \frac{1}{3}t^3,\frac{1}{2}t^2,t \rangle$, find
#
# a) the unit tangent vector
#
# $T(t) = \frac{r'(t)}{|r'(t)|}$
#
# $r'(t) = \langle t^2,\; t,\; 1 \rangle$
#
# $|r'(t)| = \sqrt{(t^2)^2 + t^2 + 1^2}$
# $\;=\; \sqrt{t^4+t^2+1}$
#
# **answer:** $T(t) = \frac{\langle t^2,\; t,\; 1\rangle}{\sqrt{t^4+t^2+1}{}}$
#
# <br>
#
# b) the unit normal vector
#
# $N(t) = \frac{T'(t)}{|T'(t)|}$
#
# <br>
#
# $T_x'(t) = \frac{d}{dt}(\frac{t^2}{\sqrt{t^4+t^2+1}})$
#
# quotient rule: $(\frac{f}{g})' = \frac{f'\cdot g-g'\cdot f}{g^2}$
# $\implies \frac{\frac{d}{dt}(t^2)\sqrt{t^4+t^2+1} - \frac{d}{dt}(\sqrt{t^4+t^2+1})t^2}{(\sqrt{t^4+t^2+1})^2}$
#
# $\frac{d}{dt}(t^2) = 2t$
#
# $\frac{d}{dt}(\sqrt{t^4+t^2+1})$
#
# $\quad \text{let } f=\sqrt{u},\; u=t^4+t^2+1$ (chain rule)
#
# $\quad \frac{d}{du}(\sqrt{u})\frac{d}{dt}(t^4+t^2+1)$
# $\;=\; \frac{1}{2\sqrt{u}} \cdot 4t^3+2t$
#
# $\quad =\; \frac{1}{2\sqrt{t^4+t^2+1}}(4t^3+2t)$
# $\;=\; \frac{t(2t^2+1)}{\sqrt{t^4+t^2+1}}$
#
# $= \frac{2t\sqrt{t^4+t^2+1}-\frac{t(2t^2+1)}{\sqrt{t^4+t^2+1}}t^2}{(\sqrt{t^4+t^2+1})^2}$
# $\;=\; \frac{t^3+2t}{(t^4+t^2+1)\sqrt{t^4+t^2+1}}$
# $\;=\; \frac{t^3+2t}{(t^4+t^2+1)^{3/2}}$
#
# <br>
#
# $T'_y(t) = \frac{d}{dt}(\frac{t}{\sqrt{t^4+t^2+1}})$
#
# quotient rule: $(\frac{f}{g})' = \frac{f'\cdot g-g'\cdot f}{g^2}$
# $\implies \frac{\frac{d}{dt}(t)\sqrt{t^4+t^2+1}-\frac{d}{dt}(\sqrt{t^4+t^2+1})t}{(\sqrt{t^4+t^2+1})^2}$
#
# $\frac{d}{dt}(t) = 1$
#
# $\frac{d}{dt}(\sqrt{t^4+t^2+1}) =\frac{t(2t^2+1)}{\sqrt{t^4+t^2+1}}$
#
# $= \frac{\sqrt{t^4+t^2+1}-\frac{t(2t^2+1)}{\sqrt{t^4+t^2+1}}t}{(\sqrt{t^4+t^2+1})^2}$
# $= \frac{-t^4+1}{(t^4+t^2+1)\sqrt{t^4+t^2+1}}$
# $= \frac{-t^4+1}{(t^4+t^2+1)^{3/2}}$
#
# <br>
#
# $T'_z(t) = \frac{d}{dt}(\frac{1}{\sqrt{t^4+t^2+1}})$
#
# $\text{let } f=u^{-1/2},\; u=(t^4+t^2+1)\quad$ (chain rule)
#
# $\frac{d}{du}(u^{-1/2})\frac{d}{dt}(t^4+t^2+1)$
# $\;=\; -\frac{1}{2u^{3/2}}\frac{d}{dt}(t^4+t^2+1)$
#
# $-\frac{1}{2(t^4+t^2+1)^{3/2}}4t^3+2t$
# $\;=\; -\frac{t(2t^2+1)}{(t^4+t^2+1)^{3/2}}$
#
# <br>
#
# $N(t) = \frac{\frac{\langle t^3+2t,\; 1-t^4,\; -2t^3-t \rangle}{(t^4+t^2+1)^{3/2}}}{\frac{\sqrt{t^8+5t^6+6t^4+5t^2+1}}{(t^4+t^2+1)^{3/2}}}$
#
# **answer:** $\frac{\langle t^3+2t,\; 1-t^4,\; -2t^3-t \rangle}{\sqrt{t^8+5t^6+6t^4+5t^2+1}}$
#
# <br>
#
# c) the curvature
#
# $k(t) = \frac{|T'(t)|}{|r'(t)|}$
# $\;=\; \frac{\frac{\sqrt{t^8+5t^6+6t^4+5t^2+1}}{(t^4+t^2+1)^{3/2}}}{\frac{\sqrt{t^4+t^2+1}}{1}}$
#
# **answer:** $\frac{\sqrt{t^8+5t^6+6t^4+5t^2+1}}{(t^4+t^2+1)^2}$

# %% [markdown]
# <hr>
#
# **13.** Find the curvature of the curve $y=x^4$ at the point $(1,1)$
#
# $k(x) = \frac{|f''(x)|}{(1+(f'(x))^2)^{3/2}}$
#
# $f(x)=x^4 \implies f'(x)=4x^3 \implies f''(x)=12x^2$
#
# $k(x) = \frac{|12x^2|}{(1+(4x^3)^2)^{3/2}}$
# $\;=\; \frac{12x^2}{(1+16x^6)^{3/2}}$
#
# At $P=(1,1):$
#
# $k(1) = \frac{12(1)^2}{(1+16(1)^6)^{3/2}}$
# $\;=\; \frac{12}{(17)^{3/2}}$
#
# **answer:** $ \frac{12}{17\sqrt{17}}$

# %% [markdown]
# <hr>
#
# **17.** A particle moves with position function
# $\boldsymbol{r}(t) = t\ln(t)\boldsymbol{i} + t\boldsymbol{j} + e^{-t}\boldsymbol{k}$.
# Find the velocity, speed, and acceleration of the particle.
#
# $v(t) = r'(t) = \langle \ln(t)+1,\; 1,\; -e^{-t}\rangle$
#
# $a(t) = v'(t) = \langle \frac{1}{t},\; 0,\; e^{-t} \rangle$
#
# $s(t) = |v(t)| = \sqrt{(\ln(t)+1)^2+1+e^{-2t}}$
