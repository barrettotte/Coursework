# %% [markdown]
# # Exam 4 - Triple Integrals and Surface Integrals in 3-space

# %% [markdown]
# **1.** a) Show that the vector field $\vec{F}=\langle e^xyz,\;e^xz+2yz,\;e^xy+y^2+1 \rangle$ is conservative.
#
# $\text{curl}\;\vec{F}=(R_y-Q_z)\hat{i}+(P_z-R_x)\hat{j}+(Q_x-P_y)\hat{k}$
#
# $P_x=yze^x,\quad P_y=e^xz,\quad P_z=e^xy$
#
# $Q_x=e^xz,\quad Q_y=2z,\quad Q_z=e^x+2y$
#
# $R_x=e^xy,\quad R_y=2y+e^x,\quad R_z=0$
#
# $\text{curl}\;\vec{F}=(2y+e^x-e^x+2y)\hat{i}$
# $+(e^xy-e^xy)\hat{j}$
# $+(e^xz-e^xz)\hat{k}$
#
# $=\langle 0,0,0 \rangle \implies \vec{F}$ is conservative
#
# <br>
#
# b) By a systematic method, find a potential for $\vec{F}$.
#
# $\int f_xdx$
# $=\int e^xyz\;dx$
# $=e^xyz+g(y,z)$
#
# $f=e^xyz+g(y,z)$
#
# $f_y=e^xz + g_y \implies g_y=2yz$
#
# <br>
#
# c) Show that the vector field $\vec{G}=\langle y,x,y \rangle$ is not conservative.
#
# $\text{curl}\;\vec{G}=(R_y-Q_z)\hat{i}+(P_z-R_x)\hat{j}+(Q_x-P_y)\hat{k}$
#
# $\text{curl}\;\vec{G}=\langle 1-0,?,? \rangle$
#
# $\text{curl}\;\vec{G} \neq \vec{0}$ so it is not conservative.

# %% [markdown]
# <hr>
#
# **2.** Let $S$ be the part of the spherical surface $x^2+y^2+z^2=4$, lying in $x^2+y^2>1$, which
# is to say outside the cylinder of radius one with axis the $z$-axis.
#
# a) Compute the flux outward through $S$ of the vector field $\vec{F}=y\hat{i}-x\hat{j}+z\hat{k}$.
#
# $\iint\limits_S\vec{F}\cdot d\vec{S}$
# $=\iint\limits_S\vec{F}\cdot \vec{n}dS$
#
# $\vec{n}=\frac{1}{2}\cdot\langle x,y,z \rangle$
#
# $\vec{F}=\langle y,-x,z \rangle$
#
# $\vec{F}\cdot\vec{n}=\langle y,-x,z\rangle\cdot \frac{1}{2}\langle x,y,z \rangle$
#
# $\vec{F}\cdot\vec{n}=\frac{z^2}{2}$
#
# convert to spherical coordinates:
# - $r=\rho\sin(\varphi)$
# - $\theta=\theta$
# - $z=\rho\cos(\varphi)$
# - $dV=\rho^2\sin(\varphi)d\rho d\theta d\varphi$
#
#
# $z=2\cos(\varphi)$
#
# $dS=4\sin(\varphi)\;d\varphi d\theta$
#
# <br>
#
# ???
#
# <br>
#
# b) Show that the flux of this vector field through any part of cylindrical surface is zero.
#
# c) Using the divergence theorem applied to $\vec{F}$, compute the volume of the region between $S$ and the cylinder.

# %% [markdown]
# <hr>
#
# **3.** Let $S$ be the part of the spherical surface $x^2+y^2+z^2=2$ lying in $z>1$.
# Orient $S$ upwards and give its bounding circle, $C$, lying in $z=1$ the compatible orientation.
#
# a) Parametrize $C$ and use the parametrization to evalute the line integral
# $I=\oint_C xzdx+ydy+ydz$.
#
# $x^2+y^2+z^2=2,\; z=1 \implies x^2+y^2=1$
#
# $\cos^2(t)+\sin^2(t)=1$
#
# $x=\cos(t),\quad y=\sin(t),\quad z=1$
#
# $dx=-\sin(t)dt,\quad dy=\cos(t)dt,\quad dz=0$
#
# $I=\oint_C xzdx+ydy+ydz$
#
# $=\int_0^{2\pi}(-\cos(t)\sin(t)+\sin(t)\cos(t))dt$
# $=\int_0^{2\pi}0dt$
# $=0$
#
# <br>
#
# b) Compute the curl of the vector field $\vec{F}=xz\hat{i}+y\hat{j}+y\hat{k}$
#
# $\text{curl}\;\vec{F}=$
# $\left(\frac{\partial R}{\partial y}-\frac{\partial Q}{\partial z}\right)\hat{i}$
# $+\left(\frac{\partial P}{\partial z}-\frac{\partial R}{\partial x}\right)\hat{j}$
# $+\left(\frac{\partial Q}{\partial x}-\frac{\partial P}{\partial y}\right)\hat{k}$
#
#
# $\text{curl}\;\vec{F}=\langle (1-0),(x-0),(0-0) \rangle$
# $=\hat{i}+x\hat{j}$
#
# <br>
#
# c) Write down a flux integral through $S$ which can be computed using the value of $I$.
#
# $\int_C\vec{F}\cdot d\vec{r}=\iint\limits_S\text{curl}\;\vec{F}\cdot d\vec{S}\quad$
# $=\iint\limits_S\text{curl}\;\vec{F}\cdot\vec{n}dS$
#
# $\text{curl}\;\vec{F}=\langle 1,x,0 \rangle$
#
# ???

# %% [markdown]
# <hr>
#
# **4.** Use the divergence theorem to compute the flux of $\vec{F}=\hat{i}+\hat{j}+\hat{k}$ outwards
# across the closed surface $x^4+y^4+z^4=1$.
#
# $\iint\limits_S\vec{F}\cdot d\vec{S}=\iiint\limits_E\text{div}\vec{F}dV$
#
# $\text{div}\;\vec{F}=\frac{\partial P}{\partial x}$
# $+\frac{\partial Q}{\partial y}+\frac{\partial R}{\partial z}$
#
# $\text{div}\;\vec{F}=0+0+0=0$
#
# $\iint\limits_S\vec{F}\cdot\vec{n}dS=\iiint\limits_E\text{div}\;\vec{F}dV=0$

# %% [markdown]
# <hr>
#
# **5.** Consider the surface $S$ given by the equation $z=(x^2+y^2+z^2)^2$.
#
# a) Show that $S$ lies in the upper half space $(z\ge 0)$
#
# $z=(x^2+y^2+z^2)^2 \ge 0$ . Even powered, always holds true
#
# <br>
#
# b) Write out the equation for the surface in spherical polar coordinates
#
# c) Using the equation obtained in part b), give an iterated integral, with explicit integrand
# and limits of integration, which gives the volume of the region inside this surface.
# Do not evaluate the integral.

# %% [markdown]
# <br>
#
# **this exam beat me up, I think I've had enough.**
#
# **For my purposes, I think I've gotten enough out of this course. Either way physics will force me to learn any missing material**
